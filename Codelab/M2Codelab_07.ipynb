# %% [markdown]
# # Exercício 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# nome das companhias aéreas - Categórico
#
# resposta do atendimento ao cliente (0 a 5) - Numerico
#
# nome da transportadora - Categórico
#
# tipo da aeronave - Categórico
#
# numero do voo - Numerico
#
# numero de passageiros - Numerico
#
# quantidade de voos que partiram - Numerico
#
# quantidade de voos que chegaram - Numerico

# %% [markdown]
# # Exercício 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Idade dos ganhadores do Oscar - Discreta
# Altura em metros - Continuo
# Salario dos professores - Continuo
# Temperatura ambiente - Continuo
# Quantidade de sapatos - Discreto
# Quilometragem registrada no odômetro - Discreto (mostra apenas km inteiros)
# Numero de planetas - Discreto
# Total de acidentes por tubarões - Discreto

# %% [markdown]
# # Exercício 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

df_titanic = pd.read_csv('/content/train.csv')
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ***PassengerId*** - Numerica Discreta
# ***Survived*** - Numerica Discreta (binária)
# ***Pclass*** - Numerica Discreta
# ***Name*** - Categórica
# ***Sex*** - Categórica
# ***Age*** - Numerica Continua (Existem valores quebrados)
# ***SibSp*** - Numerica Discreta
# ***Parch*** - Numerica Discreta
# ***Ticket*** - Categórica
# ***Fare*** - Numerica Continua
# ***Cabin*** - Numerica Discreta
# ***Embarked*** - Categórica

# %% [markdown]
# ### Distribuição de Frequencias

# %% [markdown]
# Cada passageiro tem um ***PassengerId*** diferente, então a frequencia não será calculada.
# ***Survived*** pode ter a frequencia calculada.
# ***Pclass*** pode ter a frequencia calculada.
# ***Name*** se trata de um rotulo único para cada passageiro, então a frequencia não será calculada.
# ***Sex*** pode ter a frequencia calculada.
# ***Age*** pode ter a frequencia calculada, porém, a melhor solução é que seja dividida em conjuntos para o calculo.
# ***SibSp*** pode ter a frequencia calculada.
# ***Parch*** pode ter a frequencia calculada.
# ***Ticket*** se trata de um rotulo único para cada passageiro, então a frequencia não será calculada.
# ***Fare*** pode ter a frequencia calculada, porém, a melhor solução é que seja dividida em conjuntos para o calculo.
# ***Cabin*** se trata de um rotulo único para cada passageiro, então a frequencia não será calculada.
# ***Embarked*** pode ter a frequencia calculada

# %%
df_titanic.groupby('Survived')['PassengerId'].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: PassengerId, dtype: int64

# %%
df_titanic.groupby('Pclass')['PassengerId'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: PassengerId, dtype: int64

# %%
df_titanic.groupby('Sex')['PassengerId'].count()
# Out:
# Sex
# female    314
# male      577
# Name: PassengerId, dtype: int64

# %%
df_titanic.groupby('Age')['PassengerId'].count()
# Out:
# Age
# 0.42     1
# 0.67     1
# 0.75     2
# 0.83     2
# 0.92     1
#         ..
# 70.00    2
# 70.50    1
# 71.00    2
# 74.00    1
# 80.00    1
# Name: PassengerId, Length: 88, dtype: int64

# %%
df_titanic.groupby('SibSp')['PassengerId'].count()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 3     16
# 4     18
# 5      5
# 8      7
# Name: PassengerId, dtype: int64

# %%
df_titanic.groupby('Parch')['PassengerId'].count()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 3      5
# 4      4
# 5      5
# 6      1
# Name: PassengerId, dtype: int64

# %%
df_titanic.groupby('Fare')['PassengerId'].count()
# Out:
# Fare
# 0.0000      15
# 4.0125       1
# 5.0000       1
# 6.2375       1
# 6.4375       1
#             ..
# 227.5250     4
# 247.5208     2
# 262.3750     2
# 263.0000     4
# 512.3292     3
# Name: PassengerId, Length: 248, dtype: int64

# %%
df_titanic.groupby('Embarked')['PassengerId'].count()
# Out:
# Embarked
# C    168
# Q     77
# S    644
# Name: PassengerId, dtype: int64

# %% [markdown]
# ### Representação

# %% [markdown]
# Para as variaveis onde é possivel gerar a distruição de frequencias, é possivel realizar a representação gráfica. Algumas variáveis apresentarão problemas em sua visualização devido a sua natureza e serão melhor representadas por histogramas. De forma geral, o gráfico mais adequado para as representações são:
# ***Survived*** - Barras ou Pizza
# ***Pclass*** - Barras ou Pizza
# ***Sex*** - Barras ou Pizza
# ***Age*** - Barras ou Histograma (após a separação dos conjuntos)
# ***SibSp*** - Barras ou Pizza
# ***Parch*** - Barras ou Pizza
# ***Fare*** - Barras ou Histograma (aós a separação dos conjuntos)
# ***Embarked*** - Barras ou Pizza

# %% [markdown]
# ### Representação Gráfica

# %% [markdown]
# Survived - A variável é o *target* do dataset, ela ilustra os sobreviventes, então, é uma variável que mostra informações importantes sobre a situação
# Age - a variável nos permite analisar a media das idades das pessoas no navio e tentar estabelecer alguma correlação entre idades e sobreviventes

# %%
dados = df_titanic.groupby('Age')['PassengerId'].count().reset_index().rename(columns={"PassengerId":'freq'})

sns.set_style('darkgrid')

plt.figure(figsize=[12,8])
plt.hist(df_titanic['Age'], bins = 8)
plt.title('Grafico de barras', loc='left', fontsize=18)
plt.xlabel('Idades', fontsize=14)
plt.ylabel('Contagem', fontsize=14)
# Out:
# Text(0, 0.5, 'Contagem')

# %%
dados = df_titanic.groupby('Survived')['PassengerId'].count().reset_index().rename(columns={'PassengerId':'freq'})

sns.set_style('darkgrid')

plt.figure(figsize=[12,8])
sns.barplot(x="Survived", y="freq", data=dados)
plt.title('Grafico de barras', loc='left', fontsize=18)
plt.xlabel('Survived', fontsize=14)
plt.ylabel('Count', fontsize=14)
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=[12,8])
plt.pie(dados['freq'], labels = ['Morreu', 'Sobreviveu'], autopct='%.0f%%')
plt.show()
